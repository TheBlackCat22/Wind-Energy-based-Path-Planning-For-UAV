# %%
import Windfield_Env
import Agent

# %% [markdown]
# ## Wind Field Type 1

# %%
env=Windfield_Env.WindField(size=7)
env.render()

# %%
mean_wind_field=env.generate_windfield(type=1)
env.plot_windfield(mean_wind_field)

# %%
env.generate_windfield(type=1,varying=True)
policy=Agent.value_iteration(env)

# %%
Agent.play_policy(env,policy)

# %% [markdown]
# ## Wind Field Type 2

# %%
env=Windfield_Env.WindField(size=7)

# %%
mean_wind_field=env.generate_windfield(type=2)
env.plot_windfield(mean_wind_field)

# %%
env.generate_windfield(type=2,varying=True)
policy=Agent.value_iteration(env)

# %%
Agent.play_policy(env,policy)

# %% [markdown]
# ## Wind Field Type 3

# %%
env=Windfield_Env.WindField(size=7)

# %%
mean_wind_field=env.generate_windfield(type=3)
env.plot_windfield(mean_wind_field)

# %%
env.generate_windfield(type=3,varying=True)
policy=Agent.value_iteration(env)

# %%
Agent.play_policy(env,policy)

# %% [markdown]
# ## Wind Field Type 4

# %%
env=Windfield_Env.WindField(size=7)

# %%
mean_wind_field=env.generate_windfield(type=4)
env.plot_windfield(mean_wind_field)

# %%
env.generate_windfield(type=4,varying=True)
policy=Agent.value_iteration(env)

# %%
Agent.play_policy(env,policy)
